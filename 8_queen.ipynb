# %% [markdown]
# <a href="https://colab.research.google.com/github/1997vijay/CTSDSSUMMIT2020/blob/master/8_queen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
def random_chromosome(size): #making random chromosomes 
    return [ random.randint(0, nq-1) for _ in range(nq) ]

# %%
def fitness(chromosome):
    horizontal_collisions = sum([chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = [0] * 2*n
    right_diagonal = [0] * 2*n
    for i in range(n):
        left_diagonal[i + chromosome[i] - 1] += 1
        right_diagonal[len(chromosome) - i + chromosome[i] - 2] += 1

    diagonal_collisions = 0
    for i in range(2*n-1):
        counter = 0
        if left_diagonal[i] > 1:
            counter += left_diagonal[i]-1
        if right_diagonal[i] > 1:
            counter += right_diagonal[i]-1
        diagonal_collisions += counter / (n-abs(i-n+1))
    
    return int(maxFitness - (horizontal_collisions + diagonal_collisions)) #28-(2+3)=23

# %%
def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

# %%
def random_pick(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(w for c, w in populationWithProbabilty)
    r = random.uniform(0, total)
    upto = 0
    for c, w in zip(population, probabilities):
        if upto + w >= r:
            return c
        upto += w
    assert False, "Shouldn't get here"

# %%
def reproduce(x, y): #doing cross_over between two chromosomes
    n = len(x)
    c = round(n/2)
    return x[0:c] + y[c:n]

# %%
def mutate(x):  #randomly changing the value of a random index of a chromosome
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(0, n - 1)
    x[c] = m
    return x

# %%
def genetic_queen(population, fitness):
    mutation_probability = 0.05
    new_population = []
    probabilities = [probability(n, fitness) for n in population]
    for i in range(len(population)):
        x = random_pick(population, probabilities) #best chromosome 1
        y = random_pick(population, probabilities) #best chromosome 2
        child = reproduce(x, y) #creating two new chromosomes from the best 2 chromosomes
        if random.random() < mutation_probability:
            child = mutate(child)
        print_chromosome(child)
        new_population.append(child)
        if fitness(child) == maxFitness: break
    return new_population

# %%
def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
        .format(str(chrom), fitness(chrom)))

# %%
if __name__ == "__main__":
    nq = 8
    maxFitness = (nq*(nq-1))/2  # 8*7/2 = 28
    population = [random_chromosome(nq) for _ in range(100)]
    
    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print("=== Generation {} ===".format(generation))
        population = genetic_queen(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(max([fitness(n) for n in population])))
        generation += 1
    chrom_out = []
    print("Solved in Generation {}!".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("");
            print("One of the solutions: ")
            chrom_out = chrom
            print_chromosome(chrom)
# Out:
# Streaming output truncated to the last 5000 lines.
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [1, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 14455 ===
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 2, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [1, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [5, 1, 4, 0, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 7, 7, 3, 5],  Fitness = 23
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 1, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 0, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 4, 4, 2, 6, 7, 3, 5],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14456 ===
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [5, 1, 4, 0, 6, 7, 1, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 1, 5],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 0, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 2, 3, 2],  Fitness = 23
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 2, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 4, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 0, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 5],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14457 ===
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 2, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 3],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 1, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 4, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [6, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 0, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 0, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 4, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 0, 6, 0, 3, 5],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 14458 ===
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 3, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 4, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 1, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [0, 1, 4, 0, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 0],  Fitness = 26
# Chromosome = [0, 1, 4, 0, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 2, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 1],  Fitness = 25
# Chromosome = [4, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 3],  Fitness = 23
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 2, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14459 ===
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 1, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 3],  Fitness = 24
# Chromosome = [3, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 1],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [1, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 1, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 3, 6, 7, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [7, 0, 7, 2, 6, 7, 3, 5],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 3, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 4, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 4, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 3],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14460 ===
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 7, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 7, 7, 3, 5],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 3, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [0, 1, 4, 3, 1, 7, 3, 5],  Fitness = 24
#
# Maximum Fitness = 27
# === Generation 14461 ===
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 3],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 1, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 0, 2, 6, 7, 3, 3],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 2, 3, 2],  Fitness = 23
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 0],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 3, 4, 6, 6, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 1],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 3],  Fitness = 23
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 3],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 7, 7, 3, 5],  Fitness = 23
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 3, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14462 ===
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 1, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 5],  Fitness = 24
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 0, 5, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 2, 3, 2],  Fitness = 23
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 3],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 7, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 14463 ===
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 6, 4, 2, 6, 7, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 7, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 0, 5, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 1, 0, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 4, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 1, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 2, 3, 2],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [3, 1, 4, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 1, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 7, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 3],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 3],  Fitness = 23
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 1, 4, 6, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 1, 3, 6, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 0, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 3],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 3, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# ...
# Chromosome = [0, 1, 3, 2, 0, 0, 3, 2],  Fitness = 21
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 5],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 2],  Fitness = 22
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [5, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 2, 2, 6, 7, 0, 1],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 0, 1],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [3, 5, 0, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 4],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [1, 1, 7, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [7, 1, 2, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 1, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [4, 4, 0, 2, 0, 0, 3, 2],  Fitness = 21
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [1, 1, 7, 6, 0, 0, 3, 1],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 2],  Fitness = 22
# Chromosome = [7, 1, 2, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 2, 2, 6, 7, 3, 1],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14501 ===
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [5, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 2],  Fitness = 22
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [3, 5, 0, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [1, 1, 7, 6, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 2, 2, 6, 0, 0, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 5],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [3, 5, 0, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 4, 0, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 0, 1],  Fitness = 24
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 5],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 3, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [7, 1, 2, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 2, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [5, 1, 4, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 1, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 1, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 1, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 2, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [1, 1, 7, 6, 6, 1, 3, 5],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 2, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [1, 1, 7, 6, 0, 6, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
#
# Maximum Fitness = 27
# === Generation 14502 ===
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [7, 1, 2, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [5, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 4, 0, 2, 0, 0, 3, 1],  Fitness = 23
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [3, 5, 0, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [1, 1, 7, 6, 6, 7, 3, 5],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 1],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 2],  Fitness = 22
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 0, 1],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 0, 6, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [3, 5, 0, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 6],  Fitness = 25
# Chromosome = [7, 1, 4, 4, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 6, 7, 3, 1],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 4, 2, 6, 7, 0, 1],  Fitness = 24
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 5],  Fitness = 23
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [3, 5, 0, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 2],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [3, 5, 0, 2, 6, 7, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 4, 0, 2, 6, 0, 4, 5],  Fitness = 23
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 2],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 0, 0, 3, 1],  Fitness = 24
# Chromosome = [0, 1, 6, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 2, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 6, 7, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 4, 2, 0, 0, 3, 2],  Fitness = 23
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 1, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 4, 5],  Fitness = 24
# Chromosome = [0, 1, 3, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [1, 1, 7, 6, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 2, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [7, 7, 4, 2, 0, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 2, 2, 6, 0, 0, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 2, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 0, 4, 2, 6, 1, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [3, 5, 0, 2, 6, 7, 3, 5],  Fitness = 25
#
# Maximum Fitness = 27
# === Generation 14503 ===
# Chromosome = [0, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [5, 1, 4, 2, 0, 0, 3, 2],  Fitness = 24
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [0, 1, 3, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [0, 1, 4, 2, 6, 1, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 0, 4, 5],  Fitness = 26
# Chromosome = [0, 1, 6, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 5, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [0, 1, 3, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [5, 1, 4, 2, 6, 0, 4, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 2, 2, 6, 1, 3, 5],  Fitness = 25
# Chromosome = [4, 5, 0, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 2],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 3, 5],  Fitness = 27
# Chromosome = [7, 1, 4, 2, 0, 0, 3, 1],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 0, 0, 5],  Fitness = 26
# Chromosome = [1, 1, 7, 6, 6, 7, 3, 1],  Fitness = 22
# Chromosome = [0, 1, 6, 2, 6, 0, 3, 5],  Fitness = 25
# Chromosome = [7, 1, 4, 2, 6, 7, 3, 5],  Fitness = 26
# Chromosome = [7, 1, 4, 2, 0, 6, 3, 5],  Fitness = 28
#
# Maximum Fitness = 28
# Solved in Generation 14503!
#
# One of the solutions:
# Chromosome = [7, 1, 4, 2, 0, 6, 3, 5],  Fitness = 28
